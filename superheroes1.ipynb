# %%
# standard 1st 3 lines
# %reload_ext autoreload
# %autoreload 2
#%matplotlib inline

# %%
# standard lib imports
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
torch.cuda.is_available(), torch.backends.cudnn.enabled
# Out:
# (True, True)

# %%
PATH = "data/superheroes/"
sz=224
bs=24

# %%
ls {PATH}
# Out:
# CAX_Superhero_Test/                       __MACOSX/
# CAX_Superhero_Test.zip                    Sample_Submission_Values.csv
# CAX_Superhero_Train/                      Superhero_3375_SampleSubmission.csv
# CAX_Superhero_Train.zip                   Superhero_Submission_Format.csv
# CAX_Train/                                train/
# CrowdANALYTIX-Best-Practices-2018-v1.pdf  valid/

# %%
train_path = PATH+"CAX_Train/"
train_path
# Out:
# 'data/superheroes/CAX_Train/'

# %%
ls{train_path}
# Out:
# Ant-Man/  Avengers/  Black Panther/    Catwoman/     Hulk/      Spiderman/
# Aquaman/  Batman/    Captain America/  Ghost Rider/  Iron Man/  Superman/

# %%
subd1 = [f[27:].replace(' ','_') for f in glob(train_path+'*/')]
subd1
# Out:
# ['Batman/',
#  'Black_Panther/',
#  'Ant-Man/',
#  'Captain_America/',
#  'Hulk/',
#  'Avengers/',
#  'Ghost_Rider/',
#  'Superman/',
#  'Catwoman/',
#  'Aquaman/',
#  'Iron_Man/',
#  'Spiderman/']

# %%
# create directories for train and valid sets
for s in subd1:
    # !mkdir {PATH}train/{s}
    # !mkdir {PATH}valid/{s}
# Out:
# mkdir: cannot create directory ‘data/superheroes/train/Batman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Batman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Black_Panther/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Black_Panther/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Ant-Man/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Ant-Man/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Captain_America/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Captain_America/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Hulk/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Hulk/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Avengers/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Avengers/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Ghost_Rider/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Ghost_Rider/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Superman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Superman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Catwoman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Catwoman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Aquaman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Aquaman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Iron_Man/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Iron_Man/’: File exists
# mkdir: cannot create directory ‘data/superheroes/train/Spiderman/’: File exists
# mkdir: cannot create directory ‘data/superheroes/valid/Spiderman/’: File exists

# %%
s=glob(train_path+'*/')
s
# Out:
# ['data/superheroes/CAX_Train/Batman/',
#  'data/superheroes/CAX_Train/Black_Panther/',
#  'data/superheroes/CAX_Train/Ant-Man/',
#  'data/superheroes/CAX_Train/Captain_America/',
#  'data/superheroes/CAX_Train/Hulk/',
#  'data/superheroes/CAX_Train/Avengers/',
#  'data/superheroes/CAX_Train/Ghost_Rider/',
#  'data/superheroes/CAX_Train/Superman/',
#  'data/superheroes/CAX_Train/Catwoman/',
#  'data/superheroes/CAX_Train/Aquaman/',
#  'data/superheroes/CAX_Train/Iron_Man/',
#  'data/superheroes/CAX_Train/Spiderman/']

# %%
try1 = 'data/superheroes/CAX_Train/Batman/cax_batman_train1393.jpg'
fold1 = 'data/superheroes/valid/Batman/'
# !mv {try1} {fold1}

# %%
for subd in s:
    #print(subd[27:])
    fullist = glob(subd+'*.*')
    n = len(fullist)
    vallist = get_cv_idxs(n)
    for v in vallist:
        # !mv {fullist[v]} {PATH}valid/{subd[27:]}

# %%
files = !ls {PATH}train/Batman | head
img = plt.imread(f'{PATH}train/Batman/{files[0]}')
plt.imshow(img)

# %%
img.shape
# Out:
# (260, 200, 3)

# %% [markdown]
# ## Step 1
# ### Enable data augmentation, precompute=True

# %%
arch = resnet34
data = ImageClassifierData.from_paths(PATH, bs=12,tfms=tfms_from_model(arch,sz))
learn = ConvLearner.pretrained(arch, data, precompute=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/snoopy/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:02<00:00, 38012339.92it/s]
#   2%|▏         | 6/324 [00:08<07:12,  1.36s/it]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~/stuff/myfai/fastai/dataset.py in open_image(fn)
#     203         try:
# --> 204             return cv2.cvtColor(cv2.imread(str(fn), flags), cv2.COLOR_BGR2RGB).astype(np.float32)/255
#     205         except Exception as e:
#
# error: /tmp/build/80754af9/opencv_1512687413662/work/modules/imgproc/src/color.cpp:11016: error: (-215) scn == 3 || scn == 4 in function cvtColor
#
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-31-5dfe810177a9> in <module>()
#       1 arch = resnet34
#       2 data = ImageClassifierData.from_paths(PATH, bs=12,tfms=tfms_from_model(arch,sz))
# ----> 3 learn = ConvLearner.pretrained(arch, data, precompute=True)
#
# ~/stuff/myfai/fastai/conv_learner.py in pretrained(cls, f, data, ps, xtra_fc, xtra_cut, custom_head, precompute, **kwargs)
#      99         models = ConvnetBuilder(f, data.c, data.is_multi, data.is_reg,
#     100             ps=ps, xtra_fc=xtra_fc, xtra_cut=xtra_cut, custom_head=custom_head)
# --> 101         return cls(data, models, precompute, **kwargs)
#     102
#     103     @property
#
# ~/stuff/myfai/fastai/conv_learner.py in __init__(self, data, models, precompute, **kwargs)
#      91             elif self.metrics is None:
#      92                 self.metrics = [accuracy_thresh(0.5)] if self.data.is_multi else [accuracy]
# ---> 93         if precompute: self.save_fc1()
#      94         self.freeze()
#      95         self.precompute = precompute
#
# ~/stuff/myfai/fastai/conv_learner.py in save_fc1(self)
#     144         m=self.models.top_model
#     145         if len(self.activations[0])!=len(self.data.trn_ds):
# --> 146             predict_to_bcolz(m, self.data.fix_dl, act)
#     147         if len(self.activations[1])!=len(self.data.val_ds):
#     148             predict_to_bcolz(m, self.data.val_dl, val_act)
#
# ~/stuff/myfai/fastai/model.py in predict_to_bcolz(m, gen, arr, workers)
#      11     lock=threading.Lock()
#      12     m.eval()
# ---> 13     for x,*_ in tqdm(gen):
#      14         y = to_np(m(VV(x)).data)
#      15         with lock:
#
# ~/miniconda3/envs/pt9/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     953 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     954
# --> 955             for obj in iterable:
#     956                 yield obj
#     957                 # Update and possibly print the progressbar.
#
# ~/stuff/myfai/fastai/dataloader.py in __iter__(self)
#      77         else:
#      78             with ThreadPoolExecutor(max_workers=self.num_workers) as e:
# ---> 79                 for batch in e.map(self.get_batch, iter(self.batch_sampler)):
#      80                     yield get_tensor(batch, self.pin_memory)
#      81
#
# ~/miniconda3/envs/pt9/lib/python3.6/concurrent/futures/_base.py in result_iterator()
#     584                     # Careful not to keep a reference to the popped future
#     585                     if timeout is None:
# --> 586                         yield fs.pop().result()
#     587                     else:
#     588                         yield fs.pop().result(end_time - time.time())
#
# ~/miniconda3/envs/pt9/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~/miniconda3/envs/pt9/lib/python3.6/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~/miniconda3/envs/pt9/lib/python3.6/concurrent/futures/thread.py in run(self)
#      54
#      55         try:
# ---> 56             result = self.fn(*self.args, **self.kwargs)
#      57         except BaseException as exc:
#      58             self.future.set_exception(exc)
#
# ~/stuff/myfai/fastai/dataloader.py in get_batch(self, indices)
#      66
#      67     def get_batch(self, indices):
# ---> 68         res = self.collate_fn([self.dataset[i] for i in indices], self.pad_idx)
#      69         if not self.transpose: return res
#      70         res[0] = res[0].T
#
# ~/stuff/myfai/fastai/dataloader.py in <listcomp>(.0)
#      66
#      67     def get_batch(self, indices):
# ---> 68         res = self.collate_fn([self.dataset[i] for i in indices], self.pad_idx)
#      69         if not self.transpose: return res
#      70         res[0] = res[0].T
#
# ~/stuff/myfai/fastai/dataset.py in __getitem__(self, idx)
#     163
#     164     def __getitem__(self, idx):
# --> 165         x,y = self.get_x(idx),self.get_y(idx)
#     166         return self.get(self.transform, x, y)
#     167
#
# ~/stuff/myfai/fastai/dataset.py in get_x(self, i)
#     212     def get_n(self): return len(self.y)
#     213     def get_sz(self): return self.transform.sz
# --> 214     def get_x(self, i): return open_image(os.path.join(self.path, self.fnames[i]))
#     215
#     216     def resize_imgs(self, targ, new_path):
#
# ~/stuff/myfai/fastai/dataset.py in open_image(fn)
#     204             return cv2.cvtColor(cv2.imread(str(fn), flags), cv2.COLOR_BGR2RGB).astype(np.float32)/255
#     205         except Exception as e:
# --> 206             raise OSError('Error handling image at: {}'.format(fn)) from e
#     207
#     208 class FilesDataset(BaseDataset):
#
# OSError: Error handling image at: data/superheroes/train/Ant-Man/.DS_Store

# %% [markdown]
# ## Step 2
# ### LR Find

# %%
lrf = learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  72%|███████▏  | 36/50 [00:00<00:00, 311.36it/s, loss=5.15]

# %%
learn.sched.plot()

# %% [markdown]
# ## Step 3
# ### Train last layer from precomputed activations for 1-2 epochs

# %%
learn.fit(1e-2, 2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.663319   0.175475   0.947917
#     1      0.52475    0.204011   0.90625
# [0.20401084, 0.9062500074505806]

# %% [markdown]
# ## Step 4
# ### Train last layer with data augment(precompute=False) for 2-3 epochs with cycle_len=1

# %%
tfms = tfms_from_model(resnet34, sz, 
                       aug_tfms=transforms_side_on, max_zoom=1.1)

# %%
def get_augs():
    data = ImageClassifierData.from_paths(PATH, bs=2, tfms=tfms, 
                                          num_workers=1)
    x, _ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
data = ImageClassifierData.from_paths(PATH, tfms=tfms)
learn.set_data(data, precompute=False)
# %time learn.fit(1e-2, 3, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.333538   0.115722   0.947917
#     1      0.301381   0.138598   0.9375
#     2      0.282768   0.167007   0.9375
#
# CPU times: user 475 ms, sys: 136 ms, total: 611 ms
# Wall time: 440 ms
# [0.16700722, 0.9375]

# %% [markdown]
# ## Step 5
# ### Unfreeze all layers

# %%
learn.unfreeze()

# %% [markdown]
# ## Step 6
# ### Set Learning Rate Differentials

# %%
lr = np.array([1e-4, 1e-3, 1e-2])

# %% [markdown]
# ## Step 7
# ### find learning rate again

# %%
learn.lr_find(lr/1000)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.468656   38.946022  0.623197

# %%
learn.sched.plot()

# %%
learn.sched.plot_lr()

# %% [markdown]
# ## Step 8
# ### Train full network with cycle_mult=2 until overfit

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.279352   0.12117    0.96875
#     1      0.273627   0.101111   0.960938
#     2      0.259102   0.103213   0.960938
#     3      0.252222   0.10728    0.960938
#     4      0.24344    0.096669   0.960938
#     5      0.228728   0.091589   0.960938
#     6      0.231091   0.089512   0.960938
# [0.08951155, 0.9609375]

# %%
log_preds, y = learn.TTA()
probs = np.mean(np.exp(log_preds), axis=0)
accuracy_np(probs, y), metrics.log_loss(y, probs)
# Out:
# (0.9888888888888889, 0.12355710816084159)
